# %%
# Import Libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# Loading the dataset from interwebbie

df = pd.read_csv("https://raw.githubusercontent.com/merlijn8686/meatconsumption/main/FoodBalanceSheets_E_Europe.csv")
df.head(14)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           3  Albania       2501                Population           511
# 1           3  Albania       2501                Population          5301
# 2           3  Albania       2901               Grand Total           664
# 3           3  Albania       2901               Grand Total           674
# 4           3  Albania       2901               Grand Total           684
# 5           3  Albania       2903          Vegetal Products           664
# 6           3  Albania       2903          Vegetal Products           674
# 7           3  Albania       2903          Vegetal Products           684
# 8           3  Albania       2941           Animal Products           664
# 9           3  Albania       2941           Animal Products           674
# 10          3  Albania       2941           Animal Products           684
# 11          3  Albania       2905  Cereals - Excluding Beer          5511
# ...

# %%
df.shape
# Out:
# (52375, 17)

# %%
df['Element'].unique()
# Out:
# array(['Total Population - Both sexes', 'Domestic supply quantity',
#        'Food supply (kcal/capita/day)',
#        'Protein supply quantity (g/capita/day)',
#        'Fat supply quantity (g/capita/day)', 'Production',
#        'Import Quantity', 'Stock Variation', 'Export Quantity', 'Feed',
#        'Seed', 'Losses', 'Processing', 'Other uses (non-food)',
#        'Residuals', 'Food', 'Food supply quantity (kg/capita/yr)',
#        'Tourist consumption'], dtype=object)

# %%
df2 = df[df.Item == 'Animal Products']

# %%
df2.head(14)
# Out:
#       Area Code                    Area  Item Code             Item  \
# 8             3                 Albania       2941  Animal Products
# 9             3                 Albania       2941  Animal Products
# 10            3                 Albania       2941  Animal Products
# 1284         11                 Austria       2941  Animal Products
# 1285         11                 Austria       2941  Animal Products
# 1286         11                 Austria       2941  Animal Products
# 2658         57                 Belarus       2941  Animal Products
# 2659         57                 Belarus       2941  Animal Products
# 2660         57                 Belarus       2941  Animal Products
# 3965        255                 Belgium       2941  Animal Products
# 3966        255                 Belgium       2941  Animal Products
# 3967        255                 Belgium       2941  Animal Products
# 5332         80  Bosnia and Herzegovina       2941  Animal Products
# ...

# %%
df3 = df2[df2['Element Code'] == 664]

# %%
df3.drop(['Area Code', 'Item Code', 'Element Code', 'Y2014F', 'Y2015F', 'Y2016F', 'Y2017F', 'Y2018F'], 
         axis=1).reset_index(drop=True)
# Out:
#                                                  Area             Item  \
# 0                                             Albania  Animal Products
# 1                                             Austria  Animal Products
# 2                                             Belarus  Animal Products
# 3                                             Belgium  Animal Products
# 4                              Bosnia and Herzegovina  Animal Products
# 5                                            Bulgaria  Animal Products
# 6                                             Croatia  Animal Products
# 7                                             Czechia  Animal Products
# 8                                             Denmark  Animal Products
# 9                                             Estonia  Animal Products
# 10                                            Finland  Animal Products
# 11                                             France  Animal Products
# ...

# %%
df3.to_csv('Meat_Consumption.csv')
